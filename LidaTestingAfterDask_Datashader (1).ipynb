# %%
#pip install datashader holoviews
#pip install -U lida
#%pip install -r requirements.txt
#%pip install dask datashader matplotlib plotly seaborn pandas altair
#%pip install dask[dataframe]
#pip install black
#pip install transformers
#pip install -U kaleido
#pip install holoviews bokeh datashader pandas colorcet
#pip install --upgrade cohere
#pip install e2b
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#pip install astroid
#pip install --upgrade holoviews
#pip install selenium
#pip install --upgrade ipywidgets
#pip install jupyter_bokeh
#u need geckodriver and firefox installed and have them in system path
#https://github.com/mozilla/geckodriver/releases
#download mozilla then in system path C:\Tools\geckodriver and C:\Program Files\Mozilla Firefox

# %%
#%pip install modin[ray]        pip install -U ipywidgets

# %%
#! pip install kaggle
#! mkdir ~/.kaggle
#! cp kaggle.json ~/.kaggle/
#! chmod 600 ~/.kaggle/kaggle.json
#!kaggle datasets download -d pigment/Big-Sales-Data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# test_manager.py
from lida.components.manager import Manager
import pandas as pd
from lida.components.summarizer import Summarizer
from lida.datamodel import Summary, TextGenerationConfig, Persona
from lida import llm
from lida.components.manager import Manager
from lida.datamodel import TextGenerationConfig
from lida.components.goal import GoalExplorer
from lida.components.executor import ChartExecutor
# Out:
# summarizer.py is being ifffe
# Generating new temp ?
# Hello, world!
# Goal loadeggg
# Code repair agent loaded
# manager.py is being imported with summary update

# %%
from lida.components.textgen_langchain import TextGeneratorLLM

# %%
from lida.components.agent.code_repair_agent import CodeRepairAgent

# %%
text_gen = llm(
    provider="cohere",
    model="command-xlarge-nightly",
    api_key="KYS55qCMzJTRg1dbNJxnkEsv5YQp2WQM8jjR6UEm"

)

# %%
manager = Manager(
    model_type='cohere',
    model_name='command-xlarge-nightly',
    api_key='KYS55qCMzJTRg1dbNJxnkEsv5YQp2WQM8jjR6UEm'  # Replace with your actual API key
)
# Out:
# f:\eeeeee\lida\lida\components\agent\code_repair_agent.py:165: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 1.0. Use :meth:`~Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc.` instead.
#   self.agent = initialize_agent(

# %%
from lida.utils import read_dataframe

# %%
df1 = read_dataframe("F:/eeeeee/lida/yellow_tripdata_2015-01.csv")  # or any other dataset
# Out:
# File size is 1893.96 MB.
# Loading data as a Dask DataFrame.

# %%
#df1 = read_dataframe("F:/eeeeee/lida/tests/USA_cars_datasets.csv")  # or any other dataset

# %%
df1 = read_dataframe('F:/eeeeee/lida/lida/Weather Data (US).csv')
# Out:
# File size is 7980.11 MB.
# Loading data as a Dask DataFrame.

# %%
#df1 = read_dataframe('F:/eeeeee/lida/california_housing_train.csv')

# %%
#df1 = read_dataframe('F:/eeeeee/lida/california_housing_train.csv')

# %%
#textgen_config = TextGenerationConfig(
#    temperature=0.1,
 #   max_tokens=2000,
#    stop=None
#)

#summary = manager.summarize(df1, textgen_config=textgen_config, summary_method="langchain")

# %%
from lida.datamodel import TextGenerationConfig

textgen_config = TextGenerationConfig(
    n=1,
    temperature=0.1,
    model="command-xlarge-nightly",
    use_cache=True,
    max_tokens=2000
)

# %%
summary = manager.summarize(df1, textgen_config=textgen_config, summary_method="langchain")
# Out:
# Messages sent to text_gen.generate: [{'role': 'system', 'content': '\nYou are an experienced data analyst that can annotate datasets. Your instructions are as follows:\ni) ALWAYS generate the name of the dataset and the dataset_description.\nii) ALWAYS generate a field description.\niii) ALWAYS generate a semantic_type (a single word) for each field given its values e.g., company, city, number, supplier, location, gender, longitude, latitude, URL, IP address, zip code, email, etc.\nYou must return an updated JSON dictionary without any preamble or explanation.\n'}, {'role': 'user', 'content': '\nYou are an experienced data analyst that can annotate datasets. Your instructions are as follows:\ni) ALWAYS generate the name of the dataset and the dataset_description.\nii) ALWAYS generate a field description.\niii) ALWAYS generate a semantic_type (a single word) for each field given its values e.g., company, city, number, supplier, location, gender, longitude, latitude, URL, IP address, z
# ...

# %%
summary
# Out:
# Summary(name='', file_name='', dataset_description='Weather data collected from various weather stations across the United States, including temperature, precipitation, and location information.', field_names=['ID', 'DATE', 'TMAX', 'TMIN', 'EVAP', 'PRCP', 'Latitude', 'Longitude', 'Elevation'], fields=[{'name': 'ID', 'field_description': 'Unique identifier for each weather station.', 'semantic_type': 'station_id', 'data_type': 'categorical', 'dtype': 'category', 'samples': ['USC00046027', 'US1TNMT0080', 'US1WVGL0003']}, {'name': 'DATE', 'field_description': 'Date of weather observation.', 'semantic_type': 'date', 'data_type': 'categorical', 'dtype': 'date', 'samples': ['8/28/2009', '8/31/2007', '5/26/1999']}, {'name': 'TMAX', 'field_description': 'Maximum temperature recorded on the date, in degrees Fahrenheit.', 'semantic_type': 'temperature', 'data_type': 'continuous', 'dtype': 'number', 'samples': [10.0, 273.0, 736.0]}, {'name': 'TMIN', 'field_description': 'Minimum temperature rec
# ...

# %%
persona = Persona(
        persona="A data scientist that wants visualizations of the data.",
        rationale="To generate goals that align with strategic business insights."
    )

# %%
goals = manager.goals(
       summary=summary,
       textgen_config=textgen_config,
        n=3,
        persona=persona
    )
# Out:
# summary_dict {'name': '', 'file_name': '', 'dataset_description': 'Weather data collected from various weather stations across the United States, including temperature, precipitation, and location information.', 'field_names': ['ID', 'DATE', 'TMAX', 'TMIN', 'EVAP', 'PRCP', 'Latitude', 'Longitude', 'Elevation'], 'fields': [{'name': 'ID', 'field_description': 'Unique identifier for each weather station.', 'semantic_type': 'station_id', 'data_type': 'categorical', 'dtype': 'category', 'samples': ['USC00046027', 'US1TNMT0080', 'US1WVGL0003']}, {'name': 'DATE', 'field_description': 'Date of weather observation.', 'semantic_type': 'date', 'data_type': 'categorical', 'dtype': 'date', 'samples': ['8/28/2009', '8/31/2007', '5/26/1999']}, {'name': 'TMAX', 'field_description': 'Maximum temperature recorded on the date, in degrees Fahrenheit.', 'semantic_type': 'temperature', 'data_type': 'continuous', 'dtype': 'number', 'samples': [10.0, 273.0, 736.0]}, {'name': 'TMIN', 'field_description': 'Mi
# ...

# %%
goals
# Out:
# [Goal(question='How does maximum temperature vary across different weather stations over time?', visualization='Create a line plot showing the TMAX values over time for each weather station, with each station represented by a different line.', rationale='This visualization will help identify patterns and trends in maximum temperatures across various locations, allowing us to compare how temperatures change over time at different stations.', plot_type='line', x_axis='DATE', y_axis='TMAX', color='ID', size=None, index=0),
# ...

# %%
import os
import sys

# Set up the path to include the lida directory for imports
sys.path.append('F:/eeeeee/lida/lida')  # Adjust path based on your Colab workspace if needed

# Import all components to check for errors
try:
    from lida.components.viz.vizeditor import VizEditor
    from lida.components.viz.vizevaluator import VizEvaluator
    from lida.components.viz.vizexplainer import VizExplainer
    from lida.components.viz.vizgenerator import VizGenerator
    from lida.components.viz.vizrecommender import VizRecommender
    from lida.components.viz.vizrepairer import VizRepairer
    from lida.components.executor import ChartExecutor
    from lida.components.goal import GoalExplorer
except Exception as e:
    print("Error during import:", e)
from lida import llm
from lida.components.manager import Manager
from lida.datamodel import TextGenerationConfig

# %%
import sys

# Insert your local lida package path at the beginning of sys.path
sys.path.insert(0, 'F:/eeeeee/lida')  # Adjust this path as needed

# Verify the path
print("Current sys.path:", sys.path)
# Out:
# Current sys.path: ['F:/eeeeee/lida', 'C:\\Users\\ZezoBrando\\AppData\\Local\\Programs\\Python\\Python312\\python312.zip', 'C:\\Users\\ZezoBrando\\AppData\\Local\\Programs\\Python\\Python312\\DLLs', 'C:\\Users\\ZezoBrando\\AppData\\Local\\Programs\\Python\\Python312\\Lib', 'C:\\Users\\ZezoBrando\\AppData\\Local\\Programs\\Python\\Python312', 'f:\\eeeeee\\lida\\env_lang', '', 'f:\\eeeeee\\lida\\env_lang\\Lib\\site-packages', 'f:\\eeeeee\\lida\\env_lang\\Lib\\site-packages\\win32', 'f:\\eeeeee\\lida\\env_lang\\Lib\\site-packages\\win32\\lib', 'f:\\eeeeee\\lida\\env_lang\\Lib\\site-packages\\Pythonwin', 'f:\\eeeeee\\lida\\env_lang\\Lib\\site-packages\\setuptools\\_vendor', 'F:/eeeeee/lida/lida']

# %%
import importlib

import lida.components.manager
import lida.components.scaffold
from lida.components.scaffold import ChartScaffold

importlib.reload(lida.components.manager)
from lida.components.manager import Manager
# Out:
# manager.py is being imported with summary update

# %%
#viz_gen = VizGenerator(model_type='cohere',
 #   model_name='command-xlarge-nightly',
   # api_key='3lEw7dPhMiInEez7n1CDJg0OumZNrqogGSeKfGaE')

# %%
viz_gen = VizGenerator(model_type='cohere',
    model_name='command-xlarge-nightly',
    api_key='3lEw7dPhMiInEez7n1CDJg0OumZNrqogGSeKfGaE')

# %%
codez = viz_gen.generate(summary=summary, goal=goals[0],textgen_config=textgen_config, library='datashader')
codez
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #canvas.points for scatterplot , canvas.line for line plot
#     agg = canvas.points(data, 'DATE', 'TMAX')
#     img = tf.shade(agg)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='DATE',
#         ylabel='TMAX',
#         title='How does maximum temperature vary across different weather stations over time?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)

# %%
fffff

# %%
exec = ChartExecutor()
charts = exec.execute(
            code_specs=codez,
            data=df1,
            summary=summary,
            library="datashader",
            return_error=True
        )
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Code specs: ['```python\nimport datashader as ds\nimport datashader.transfer_functions as tf\nimport holoviews as hv\nimport pandas as pd\n\nhv.extension("bokeh")\n\n\ndef plot(data):\n    canvas = ds.Canvas(plot_width=800, plot_height=600)\n    agg = canvas.points(data, "median_income", "total_bedrooms")\n    img = tf.shade(agg)\n\n    hv_img = hv.Image(img)\n    plot = hv_img.opts(\n        width=800,\n        height=600,\n        xlabel="Median Income",\n        ylabel="Total Bedrooms",\n        title="Bedrooms vs Income",\n        colorbar=True,\n    )\n\n    return plot\n```']
# Code before repair: import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
#
# hv.extension("bokeh")
#
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
# ...

# %%
manager = Manager(
    model_type='cohere',
    model_name='command-xlarge-nightly',
    api_key='KYS55qCMzJTRg1dbNJxnkEsv5YQp2WQM8jjR6UEm'  # Replace with your actual API key
)
# Out:
# Hello, world!

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Generating new temp ?
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'longitude', 'latitude')
#     img = tf.shade(agg)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='longitude',
#         ylabel='latitude',
#         title='How does the median house value vary across different locations in California?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Generating new temp ?
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'longitude', 'latitude')
#     img = tf.shade(agg)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='longitude',
#         ylabel='latitude',
#         title='How does the median house value vary across different locations in California?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'housing_median_age', 'total_rooms')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='housing_median_age',
#         ylabel='total_rooms',
#         title='Is there a relationship between the age of housing and the total number of rooms?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'population', 'median_income')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='population',
#         ylabel='median_income',
#         title='How does the median income vary across different population sizes in California?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'median_income', 'total_bedrooms')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='median_income',
#         ylabel='total_bedrooms',
#         title='Are there differences in the number of bedrooms across various income levels?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# ...

# %%
import datashader as ds
import datashader.transfer_functions as tf
import holoviews as hv
import pandas as pd
import matplotlib.pyplot as plt
import dask.dataframe as dd

hv.extension("bokeh")
def plot(data):
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, "median_income", "total_bedrooms")
    img = tf.shade(agg)
    hv_img = hv.Image(img)
    plot = hv_img.opts(
        width=800,
        height=600,
        xlabel="Median Income",
        ylabel="Total Bedrooms",
        title="Bedrooms vs Income",
        colorbar=True,
    )
    return plot

chart = plot(df1)
chart
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='8c50d471-e084-4c41-ae20-d1189eababdc'>
#   <div id="b93a07da-6b08-49b7-8137-6695848f9655" data-root-id="8c50d471-e084-4c41-ae20-d1189eababdc" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 fff
#
# NameError: name 'fff' is not defined

# %%
df1.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
import datashader as ds
import datashader.transfer_functions as tf
import holoviews as hv
import pandas as pd

hv.extension("bokeh")

def plot(data):
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, "total_rooms", "median_income")
    img = tf.shade(agg)
    
    hv_img = hv.Image(img)
    plot = hv_img.opts(
        width=800,
        height=600,
        xlabel="total_bedrooms",
        ylabel="median_house_value",
        title="Patterns between Bedrooms and House Value",
        tools=["hover"],
        colorbar=True,
    )
    return plot


chart = plot(df1)
chart
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='85f6bf18-0b47-4357-a127-b77c7f52fc47'>
#   <div id="b4a2016d-1b8c-498f-bbbc-465bdae7e992" data-root-id="85f6bf18-0b47-4357-a127-b77c7f52fc47" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('bokeh')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'longitude', 'latitude')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         width=800,
#         height=600,
#         xlabel='longitude',
#         ylabel='latitude',
#         title='How does the median house value vary across different locations in California?',
#         colorbar=True
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'Latitude', 'Longitude')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         xlabel='Latitude',
#         ylabel='Longitude',
#         title='Are there any correlations between latitude, longitude, and temperature extremes?',
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'Elevation', 'Average PRCP')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         xlabel='Elevation',
#         ylabel='Average PRCP',
#         title='How does precipitation vary across different elevations?',
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# Template:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
# from colorcet import fire
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     # Insert plotting code below. No placeholders. Example:
#     # sns.scatterplot(data=data, x='DATE', y='TMAX')
#     # plt.xlabel('DATE')
#     # plt.ylabel('TMAX')
#     # plt.title('How does maximum temperature vary across different weather stations over time?', wrap=True)
#     return plt
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# Template:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
# from colorcet import fire
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     # Insert plotting code below. No placeholders. Example:
#     # sns.scatterplot(data=data, x='Latitude', y='Longitude')
#     # plt.xlabel('Latitude')
#     # plt.ylabel('Longitude')
#     # plt.title('Are there any correlations between latitude, longitude, and temperature extremes?', wrap=True)
#     return plt
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Encountered an exception when converting data source to a pandas DataFrame. See traceback above for details.
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# Template:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
# from colorcet import fire
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     # Insert plotting code below. No placeholders. Example:
#     # sns.scatterplot(data=data, x='Elevation', y='Average PRCP')
#     # plt.xlabel('Elevation')
#     # plt.ylabel('Average PRCP')
#     # plt.title('How does precipitation vary across different elevations?', wrap=True)
#     return plt
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Encountered an exception when converting data source to a pandas DataFrame. See traceback above for details.
# ERROR:lida.components.executor:Code that caused error:
# ...

# %%
import time
import tracemalloc
from functools import wraps
from datetime import datetime
import psutil
import os

def measure_visualization_performance(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        # Start trackers
        process = psutil.Process(os.getpid())
        start_memory = process.memory_info().rss / 1024 / 1024  # MB
        tracemalloc.start()
        start_time = time.perf_counter()
        
        # Execute visualization
        result = func(*args, **kwargs)
        
        # Collect metrics
        end_time = time.perf_counter()
        current, peak = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        end_memory = process.memory_info().rss / 1024 / 1024  # MB
        
        # Print metrics
        print(f"\n=== Performance Metrics ===")
        print(f"Execution Time: {end_time - start_time:.2f} seconds")
        print(f"Memory Usage: {end_memory - start_memory:.2f} MB")
        print(f"Peak Memory: {peak / 1024 / 1024:.2f} MB")
        print("========================\n")
        
        return result
    return wrapper

# Usage in notebook:
@measure_visualization_performance
def run_visualization(manager, data, summary, goal, config, library):
    return manager.visualize(
        data=data,
        summary=summary,
        goal=goal,
        textgen_config=config,
        library=library,
        return_error=True
    )

# Execute
charts = run_visualization(
    manager=manager,
    data=df1,
    summary=summary,
    goal=goals[0],
    config=textgen_config,
    library='datashader'
)
charts[0]

# %%
"""import datashader as ds
import datashader.transfer_functions as tf
import holoviews as hv
import pandas as pd
import dask.dataframe as dd
from colorcet import fire

hv.extension('matplotlib')

def plot(data):
    
    data = data.compute()
    
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, 'trip_distance', 'total_amount')
    img = tf.shade(agg, cmap=fire)
    
    hv_ds = hv.Image(img.data)
    plot = hv_ds.opts(
        xlabel='Trip Distance',
        ylabel='Total Amount',
        title='Trip Distance vs Total Amount',
    )
    
    return plot

# Execute visualization
chart = plot(df1)
chart"""
# Out:
# "import datashader as ds\nimport datashader.transfer_functions as tf\nimport holoviews as hv\nimport pandas as pd\nimport dask.dataframe as dd\nfrom colorcet import fire\n\nhv.extension('matplotlib')\n\ndef plot(data):\n    \n    data = data.compute()\n    \n    canvas = ds.Canvas(plot_width=800, plot_height=600)\n    agg = canvas.points(data, 'trip_distance', 'total_amount')\n    img = tf.shade(agg, cmap=fire)\n    \n    hv_ds = hv.Image(img.data)\n    plot = hv_ds.opts(\n        xlabel='Trip Distance',\n        ylabel='Total Amount',\n        title='Trip Distance vs Total Amount',\n    )\n    \n    return plot\n\n# Execute visualization\nchart = plot(df1)\nchart"

# %%
# Import required libraries
from dataclasses import dataclass
from typing import Optional
import pandas as pd
from lida.components.manager import Manager 
from lida.datamodel import TextGenerationConfig

# Define Goal class
@dataclass
class Goal:
    question: str
    visualization: str
    rationale: str
    plot_type: str
    x_axis: str
    y_axis: str
    color: Optional[str] = None
    size: Optional[str] = None
    index: int = 0

# Create array of visualization goals
goals = [
    Goal(
        question="How does trip distance vary with passenger counts??",
        visualization="Create a scatter showing trip distance distribution for different passenger counts",
        rationale="This will help identify if there's a relationship between number of passengers and trip length",
        plot_type="scatter",
        x_axis="passenger_count",
        y_axis="trip_distance",
        index=0
    ),
    Goal(
        question="What is the distribution of fares throughout the ddays?",
        visualization="Create a line plot showing average fare amount by hour of day",
        rationale="This helps identify peak pricing periods",
        plot_type="line",
        x_axis="hour",
        y_axis="fare_amount",
        index=1
    ),
    Goal(
        question="How do tips vary with total fffare aamount?",
        visualization="Create a scatter plot of tip amount vs total fare",
        rationale="This shows tipping patterns based on fare amounts",
        plot_type="scatter",
        x_axis="total_amount",
        y_axis="tip_amount",
        index=2
    ),
    Goal(
        question="When are the busiest times for tttaxi pickups?",
        visualization="Create a bar chart showing the number of pickups by hour of the day.",
        rationale="This helps identify peak demand hours for taxi services.",
        plot_type="bar",
        x_axis="hour",
        y_axis="pickup_count",
        index=3
    ),
    
    Goal(
        question="What are the most commonn pickup and dropoff locations?",
        visualization="Create a heatmap showing density of pickups and dropoffs based on longitude and latitude.",
        rationale="This identifies areas with the highest taxi activity.",
        plot_type="heatmap",
        x_axis="pickup_longitude",
        y_axis="pickup_latitude",
        color="density",
        index=4
    ),
    Goal(
        question="How does payment methoddd influence tipping behavior?",
        visualization="Create a boxplot cvshowing tip amounts for each payment type.",
        rationale="This helps understand if passengers tip more with specific payment methods.",
        plot_type="boxplot",
        x_axis="payment_type",
        y_axis="tip_amount",
        index=5
    ),
    Goal(
        question="How do toll amounts impaaacct the total fare?",
        visualization="Create a scatter plot of toll amounts vs total fare.",
        rationale="This examines the relationship between tolls and the total amount paid.",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=6
    ),
    Goal(
        question="What is the distribution of trip distances and how does it relate to the total amount paid?",
        visualization="Create a scatter plot showing trip distance vs total amount",
        rationale="This shows how distance affects total cost",
        plot_type="scatter",
        x_axis="trip_distance",
        y_axis="total_amount",
        index=7
    ),
]

# %%
exec = ChartExecutor()
charts = exec.execute(
            code_specs=codez,
            data=df1,
            summary=summary,
            library="datashader",
            return_error=True
        )
charts[0]

# %%
#repair_agent = CodeRepairAgent(text_gen=text_gen, 
  #                           textgen_config=textgen_config)

# %%
test_code1 ="""
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import dask.dataframe as dd

def plot(data):
    if isinstance(data, dd.DataFrame):
        data = data.compute()

    # Convert hour to a 24-hour format for plotting
    data['hour'] = data['hour'].apply(lambda x: x if 0 <= x < 24 else None)

    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.line(data, 'hour', 'fare_amount')
    img = tf.shade(agg)
    return img

chart = plot(df1)
"""
#fixed_coded = repair_agent.repair(test_code)

#print(fixed_coded)

# %%
# Import required libraries
from dataclasses import dataclass
from typing import Optional
import pandas as pd
from lida.components.manager import Manager 
from lida.datamodel import TextGenerationConfig

# Define Goal class
@dataclass
class Goal:
    question: str
    visualization: str
    rationale: str
    plot_type: str
    x_axis: str
    y_axis: str
    color: Optional[str] = None
    size: Optional[str] = None
    index: int = 0

# Create array of visualization goals
goals = [
    Goal(
        question="How does trip distance vary with passenger counts??",
        visualization="Create a scatter showing trip distance distribution for different passenger counts",
        rationale="This will help identify if there's a relationship between number of passengers and trip length",
        plot_type="scatter",
        x_axis="passenger_count",
        y_axis="trip_distance",
        index=0
    ),
    Goal(
        question="What is the distribution of fares throughout the ddays?",
        visualization="Create a line plot showing average fare amount by hour of day",
        rationale="This helps identify peak pricing periods",
        plot_type="line",
        x_axis="hour",
        y_axis="fare_amount",
        index=1
    ),
    Goal(
        question="How do tips vary with total fffare aamount?",
        visualization="Create a scatter plot of tip amount vs total fare",
        rationale="This shows tipping patterns based on fare amounts",
        plot_type="scatter",
        x_axis="total_amount",
        y_axis="tip_amount",
        index=2
    ),
    Goal(
        question="When are the busiest times for tttaxi pickups?",
        visualization="Create a bar chart showing the number of pickups by hour of the day.",
        rationale="This helps identify peak demand hours for taxi services.",
        plot_type="bar",
        x_axis="hour",
        y_axis="pickup_count",
        index=3
    ),
    
    Goal(
        question="What are the most commonn pickup and dropoff locations?",
        visualization="Create a heatmap showing density of pickups and dropoffs based on longitude and latitude.",
        rationale="This identifies areas with the highest taxi activity.",
        plot_type="heatmap",
        x_axis="pickup_longitude",
        y_axis="pickup_latitude",
        color="density",
        index=4
    ),
    Goal(
        question="How does payment methoddd influence tipping behavior?",
        visualization="Create a boxplot cvshowing tip amounts for each payment type.",
        rationale="This helps understand if passengers tip more with specific payment methods.",
        plot_type="boxplot",
        x_axis="payment_type",
        y_axis="tip_amount",
        index=5
    ),
    Goal(
        question="How do toll amounts impaaacct the total fare?",
        visualization="Create a scatter plot of toll amounts vs total fare.",
        rationale="This examines the relationship between tolls and the total amount paid.",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=6
    ),
    Goal(
        question="What is the distribution of trip distances and how does it relate to the total amount paid?",
        visualization="Create a scatter plot showing trip distance vs total amount",
        rationale="This shows how distance affects total cost",
        plot_type="scatter",
        x_axis="trip_distance",
        y_axis="total_amount",
        index=7
    ),
    Goal(
        question="How does RateCodeID affect fare amounts?",
        visualization="Create a scatter plot of fares by rate code",
        rationale="Shows pricing variation across rate codes",
        plot_type="scatter",
        x_axis="RateCodeID",
        y_axis="fare_amount",
        index=8
    ),
    Goal(
        question="What's the relationship between pickup and dropoff distances?",
        visualization="Create a scatter plot of pickup to dropoff distances",
        rationale="Reveals common trip distance patterns",
        plot_type="scatter",
        x_axis="pickup_longitude",
        y_axis="dropoff_longitude",
        index=9
    ),
    Goal(
        question="How do tolls affect total trip cost?",
        visualization="Create a scatter showing relationship between tolls and total amount",
        rationale="Shows impact of tolls on final fare",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=10
    ),
    Goal(
        question="What's the distribution of trip durations?",
        visualization="Create a histogram of trip duration in minutes",
        rationale="Shows common trip duration patterns",
        plot_type="line",
        x_axis="duration_minutes",
        y_axis="count",
        index=11
    ),
    Goal(
        question="How do extra charges vary by time of day?",
        visualization="Create a line plot of average extra charges by hour",
        rationale="Identifies peak surcharge periods",
        plot_type="line",
        x_axis="hour",
        y_axis="extra",
        index=12
    )
]

# %%
#Import required libraries
from dataclasses import dataclass
from typing import Optional
import pandas as pd
from lida.components.manager import Manager 
from lida.datamodel import TextGenerationConfig

# Define Goal class
@dataclass
class Goal:
    question: str
    visualization: str
    rationale: str
    plot_type: str
    x_axis: str
    y_axis: str
    color: Optional[str] = None
    size: Optional[str] = None
    index: int = 0

# Create array of visualization goals
goals = [
    Goal(
        question="Does the hour of the day influence additional charges?",
        visualization="Generate a line plot showing average extra charges per hour of the day.",
        rationale="Helpful for identifying peak surcharge periods.",
        plot_type="line",
        x_axis="hour",
        y_axis="extra",
        index=0
    ),
    Goal(
        question="What is the pattern of trip durations?",
        visualization="Create a histogram displaying the frequency of trip durations in minutes.",
        rationale="This will reveal common trip duration trends.",
        plot_type="line",
        x_axis="duration_minutes",
        y_axis="count",
        index=1
    ),
    Goal(
        question="Is there a connection between tolls paid and the overall fare amount?",
        visualization="Generate a scatter plot showcasing toll amounts versus total fare.",
        rationale="This can highlight the relationship between tolls and the final trip cost.",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=2
    ),
    Goal(
        question="How do pickup and dropoff locations relate?",
        visualization="Create a scatter plot comparing pickup and dropoff distances.",
        rationale="Useful for discovering common trip distance patterns.",
        plot_type="scatter",
        x_axis="pickup_longitude",
        y_axis="dropoff_longitude",
        index=3
    ),
    Goal(
        question="What impact does the RateCodeID have on the fare?",
        visualization="Generate a scatter plot showing fare amounts by rate code.",
        rationale="Helps to compare fare variations based on rate codes.",
        plot_type="scatter",
        x_axis="RateCodeID",
        y_axis="fare_amount",
        index=4
    ),
    Goal(
        question="How do distances covered influence the total trip cost?",
        visualization="Create a scatter plot displaying trip distance versus total fare amount.",
        rationale="Highlights the correlation between distance traveled and cost.",
        plot_type="scatter",
        x_axis="trip_distance",
        y_axis="total_amount",
        index=5
    ),
    Goal(
        question="How do toll charges affect the total amount paid?",
        visualization="Create a scatter plot comparing toll charges against the total fare.",
        rationale="Examines how toll fees contribute to the total fare.",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=6
    ),
    Goal(
        question="Do payment methods influence tipping habits?",
        visualization="Generate a boxplot to display tip amounts by payment type.",
        rationale="Useful for examining tipping patterns based on payment methods.",
        plot_type="boxplot",
        x_axis="payment_type",
        y_axis="tip_amount",
        index=7
    ),
    Goal(
        question="Where do taxi pickups and drop-offs occur most frequently?",
        visualization="Create a heatmap showing the density of pickups and drop-offs using longitude and latitude.",
        rationale="Helps identify the busiest areas for taxi activity.",
        plot_type="heatmap",
        x_axis="pickup_longitude",
        y_axis="pickup_latitude",
        color="density",
        index=8
    ),
    Goal(
        question="At what times of the day are taxi pickups the highest?",
        visualization="Create a bar chart showing the number of pickups per hour.",
        rationale="Useful for identifying peak demand hours for taxis.",
        plot_type="bar",
        x_axis="hour",
        y_axis="pickup_count",
        index=9
    ),
    Goal(
        question="How does the total fare impact tip amounts?",
        visualization="Create a scatter plot showing tip amount versus total fare paid.",
        rationale="Useful for examining tipping patterns based on fare amounts.",
        plot_type="scatter",
        x_axis="total_amount",
        y_axis="tip_amount",
        index=10
    ),
    Goal(
        question="What's the pattern of fares throughout the day?",
        visualization="Generate a line plot displaying the average fare amount per hour.",
        rationale="This can help identify peak fare periods.",
        plot_type="line",
        x_axis="hour",
        y_axis="fare_amount",
        index=11
    ),
    Goal(
        question="How does trip distance relate to passenger counts?",
        visualization="Create a scatter plot showing trip distance for various passenger counts.",
        rationale="Helps identify if trip length varies with the number of passengers.",
        plot_type="scatter",
        x_axis="passenger_count",
        y_axis="trip_distance",
        index=12
    )
]

# %%
"""import datashader as ds
import holoviews as hv
import pandas as pd
import matplotlib.pyplot as plt
import dask.dataframe as dd

hv.extension("bokeh")
def plot(data):
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, "trip_distance", "total_amount")
    img = ds.transfer_functions.shade(agg)
    hv_img = hv.Image(img)
    plot = hv_img.opts(
        width=800,
        height=600,
        xlabel="trip_distance",
        ylabel="total_amount",
        title="What is the distribution of trip distances and how does it relate to the total amount paid?",
    )
    return plot
chart = plot(df1)
chart"""
# Out:
# 'import datashader as ds\nimport holoviews as hv\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport dask.dataframe as dd\n\nhv.extension("bokeh")\ndef plot(data):\n    canvas = ds.Canvas(plot_width=800, plot_height=600)\n    agg = canvas.points(data, "trip_distance", "total_amount")\n    img = ds.transfer_functions.shade(agg)\n    hv_img = hv.Image(img)\n    plot = hv_img.opts(\n        width=800,\n        height=600,\n        xlabel="trip_distance",\n        ylabel="total_amount",\n        title="What is the distribution of trip distances and how does it relate to the total amount paid?",\n    )\n    return plot\nchart = plot(df1)\nchart'

# %%
import time
import tracemalloc
from functools import wraps
from datetime import datetime
import psutil
import os

def measure_visualization_performance(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        # Start trackers
        process = psutil.Process(os.getpid())
        start_memory = process.memory_info().rss / 1024 / 1024  # MB
        tracemalloc.start()
        start_time = time.perf_counter()
        
        # Execute visualization
        result = func(*args, **kwargs)
        
        # Collect metrics
        end_time = time.perf_counter()
        current, peak = tracemalloc.get_traced_memory()
        tracemalloc.stop()
        end_memory = process.memory_info().rss / 1024 / 1024  # MB
        
        # Print metrics
        print(f"\n=== Performance Metrics ===")
        print(f"Execution Time: {end_time - start_time:.2f} seconds")
        print(f"Memory Usage: {end_memory - start_memory:.2f} MB")
        print(f"Peak Memory: {peak / 1024 / 1024:.2f} MB")
        print("========================\n")
        
        return result
    return wrapper

# Usage in notebook:
@measure_visualization_performance
def run_visualization(manager, data, summary, goal, config, library):
    return manager.visualize(
        data=data,
        summary=summary,
        goal=goal,
        textgen_config=config,
        library=library,
        return_error=True
    )

# Execute
charts = run_visualization(
    manager=manager,
    data=df1,
    summary=summary,
    goal=goals[2],
    config=textgen_config,
    library='datashader'
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Insert plotting code below. Example:
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'tolls_amount', 'total_amount')
#     img = tf.shade(agg, cmap=fire)
#
#     hv_ds = hv.Image(img.data)
#     plot = hv_ds.opts(
#         xlabel='tolls_amount',
#         ylabel='total_amount',
#         title='Is there a connection between tolls paid and the overall fare amount?',
#     )
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
ff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ff
#
# NameError: name 'ff' is not defined

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'hour', 'extra')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='hour',
#     #    ylabel='extra',
#     #    title='Does the hour of the day influence additional charges?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'duration_minutes', 'count')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='duration_minutes',
#     #    ylabel='count',
#     #    title='What is the pattern of trip durations?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'tolls_amount', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='tolls_amount',
#     #    ylabel='total_amount',
#     #    title='Is there a connection between tolls paid and the overall fare amount?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'pickup_longitude', 'dropoff_longitude')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='pickup_longitude',
#     #    ylabel='dropoff_longitude',
#     #    title='How do pickup and dropoff locations relate?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'RateCodeID', 'fare_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='RateCodeID',
#     #    ylabel='fare_amount',
#     #    title='What impact does the RateCodeID have on the fare?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'trip_distance', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='trip_distance',
#     #    ylabel='total_amount',
#     #    title='How do distances covered influence the total trip cost?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[6],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Code repair agent loaded
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'tolls_amount', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='tolls_amount',
#     #    ylabel='total_amount',
#     #    title='How do toll charges affect the total amount paid?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[7],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'payment_type', 'tip_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='payment_type',
#     #    ylabel='tip_amount',
#     #    title='Do payment methods influence tipping habits?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[8],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'pickup_longitude', 'pickup_latitude')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='pickup_longitude',
#     #    ylabel='pickup_latitude',
#     #    title='Where do taxi pickups and drop-offs occur most frequently?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[9],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'hour', 'pickup_count')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='hour',
#     #    ylabel='pickup_count',
#     #    title='At what times of the day are taxi pickups the highest?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[10],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'total_amount', 'tip_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='total_amount',
#     #    ylabel='tip_amount',
#     #    title='How does the total fare impact tip amounts?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[11],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'hour', 'fare_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='hour',
#     #    ylabel='fare_amount',
#     #    title='What's the pattern of fares throughout the day?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[12],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'passenger_count', 'trip_distance')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='passenger_count',
#     #    ylabel='trip_distance',
#     #    title='How does trip distance relate to passenger counts?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[7],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas()
#     agg = canvas.line(data, 'tpep_pickup_datetime', 'tip_amount', ds.by('payment_type'))
#     img = tf.shade(agg)
#     return img
# chart = plot(data)
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
# ...

# %%
asdasda
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 asdasda
#
# NameError: name 'asdasda' is not defined

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[7],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'trip_distance', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='trip_distance',
#     #    ylabel='total_amount',
#     #    title='What is the distribution of trip distances and how does it relate to the total amount paid?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[8],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'RateCodeID', 'fare_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='RateCodeID',
#     #    ylabel='fare_amount',
#     #    title='How does RateCodeID affect fare amounts?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[9],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'pickup_longitude', 'dropoff_longitude')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='pickup_longitude',
#     #    ylabel='dropoff_longitude',
#     #    title='What's the relationship between pickup and dropoff distances?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[10],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'tolls_amount', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='tolls_amount',
#     #    ylabel='total_amount',
#     #    title='How do tolls affect total trip cost?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[11],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'duration_minutes', 'count')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='duration_minutes',
#     #    ylabel='count',
#     #    title='What's the distribution of trip durations?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[12],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'hour', 'extra')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='hour',
#     #    ylabel='extra',
#     #    title='How do extra charges vary by time of day?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[7],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'trip_distance', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='trip_distance',
#     #    ylabel='total_amount',
#     #    title='What is the distribution of trip distances and how does it relate to the total amount paid?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'passenger_count', 'trip_distance')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='passenger_count',
#     #    ylabel='trip_distance',
#     #    title='How does trip distance vary with passenger counts??',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'total_amount', 'tip_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='total_amount',
#     #    ylabel='tip_amount',
#     #    title='How do tips vary with total fffare aamount?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'hour', 'pickup_count')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='hour',
#     #    ylabel='pickup_count',
#     #    title='When are the busiest times for tttaxi pickups?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'pickup_longitude', 'pickup_latitude')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='pickup_longitude',
#     #    ylabel='pickup_latitude',
#     #    title='What are the most commonn pickup and dropoff locations?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[7],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# Template:
# import datashader as ds
# import datashader.transfer_functions as tf
# import holoviews as hv
# import pandas as pd
# import dask.dataframe as dd
# from colorcet import fire
#
# hv.extension('matplotlib')
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     #canvas = ds.Canvas(plot_width=800, plot_height=600)
#     #agg = canvas.points(data, 'trip_distance', 'total_amount')
#     #img = tf.shade(agg, cmap=fire)
#     #hv_ds = hv.Image(img.data)
#     #plot = hv_ds.opts(
#     #    xlabel='trip_distance',
#     #    ylabel='total_amount',
#     #    title='What is the distribution of trip distances and how does it relate to the total amount paid?',
#     #)
#
#     return plot
#
# #always type the below line at the end of the code
# chart = plot(data)
#
# ...

# %%
fasfasgasg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 fasfasgasg
#
# NameError: name 'fasfasgasg' is not defined

# %%
import datashader as ds
import pandas as pd
import matplotlib.pyplot as plt
import dask.dataframe as dd

def plot(data):
    canvas = ds.Canvas(plot_width=400, plot_height=400)
    agg = canvas.line(data, 'payment_type', 'tip_amount')
    img = ds.transfer_functions.dynspread(agg)
    return img
chart = plot(df1)
chart
# Out:
# <xarray.DataArray (tip_amount: 400, payment_type: 400)> Size: 160kB
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False]])
# Coordinates:
#   * payment_type  (payment_type) float64 3kB 1.005 1.015 1.025 ... 4.985 4.995
#   * tip_amount    (tip_amount) float64 3kB 4.846e+03 1.472e+04 ... 3.946e+06
# Attributes:
#     x_range:  (1.0, 5.0)
#     y_range:  (-92.42, 3950588.8)

# %%
viz_gen = VizGenerator(model_type='cohere',
    model_name='command-xlarge-nightly',
    api_key='3lEw7dPhMiInEez7n1CDJg0OumZNrqogGSeKfGaE')

# %%
codez = viz_gen.generate(summary=summary, goal=goals[5],textgen_config=textgen_config, library='datashader')

# %%
codez
# Out:
# ["```python\nimport datashader as ds\nimport datashader.transfer_functions as tf\nimport pandas as pd\nimport dask.dataframe as dd\n\ndef plot(data):\n    if isinstance(data, dd.DataFrame):\n        data = data.compute()\n    canvas = ds.Canvas(plot_width=400, plot_height=400)\n    agg = canvas.line(data, 'payment_type', 'tip_amount')\n    img = tf.shade(agg)\n    return img\n\nchart = plot(data)\n```"]

# %%
x = ChartExecutor()

# %%
charts = x.execute(
            code_specs=codez,
            data=df1,
            summary=summary,
            library="datashader",
            return_error=True
        )
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid

# %%
charts
# Out:
# [ChartExecutorResponse(spec=None, status=True, raster='...', code="import datashader as ds\nimport datashader.transfer_functions as tf\nimport pandas as pd\nimport dask.dataframe as dd\nimport matplotlib.pyplot as plt\n\ndef plot(data):\n    if isinstance(data, dd.DataFrame):\n        data = data.compute()\n    canvas = ds.Canvas(plot_width=400, plot_height=400)\n    agg = canvas.line(data, 'payment_type', 'tip_amount')\n    img = tf.shade(agg)\n    return img\nchart = plot(data)", library='datashader', error=None)]

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import datashader as ds
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, 'year', 'price')
#     img = ds.transfer_functions.dynspread(ds.transfer_functions.shade(agg))
#     return img
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=600, plot_height=400)
#     agg = canvas.points(data, 'mileage', 'price')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.line(data, 'model', 'state', agg=ds.count())
#     img = tf.shade(agg, cmap=['lightgray', 'darkgray'])
#     return img
# chart = plot(data)
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.line(data, 'model', 'state', agg=ds.count())
#     img = tf.shade(agg, cmap=['lightgray', 'darkgray'])
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.line(data, 'title_status', 'price')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: x must be real
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.points(data, 'color', 'price')
#     img = ds.transfer_functions.shade(agg)
#     return img
# chart = plot(data)
# import datashader as ds
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.points(data, 'color', 'price')
#     img = ds.transfer_functions.shade(agg)
#     return img
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[6],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='condition', y='price')
#     return sns
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     sns.boxplot(x="color", y="price", data=data)
#     plt.xlabel("Color")
#     plt.ylabel("Auction Price")
#     plt.title("Auction Price Distribution by Vehicle Color")
#     return plt
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.boxplot(x="title_status", y="price", data=data)
#     plt.xlabel("Title Status")
#     plt.ylabel("Auction Price")
#     plt.title("How does the title status affect auction prices?")
#     return plt
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     sns.countplot(data=data, x='state', hue='model')
#     plt.xlabel('State')
#     plt.ylabel('Count')
#     plt.title('Vehicle Model Popularity by State')
#     return plt
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='mileage', y='price')
#     return sns
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     sns.scatterplot(data=data, x="year", y="price")
#     plt.xlabel("Year")
#     plt.ylabel("Auction Price")
#     plt.title("Auction Prices Over the Years")
#     return plt
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     sns.boxplot(x="brand", y="price", data=data)
#     plt.xlabel("Brand")
#     plt.ylabel("Price")
#     plt.title("How does vehicle price vary across different brands?")
#     return plt
#
# chart = plot(data)

# %%
# Import required libraries
from dataclasses import dataclass
from typing import Optional
import pandas as pd
from lida.components.manager import Manager 
from lida.datamodel import TextGenerationConfig

# Define Goal class
@dataclass
class Goal:
    question: str
    visualization: str
    rationale: str
    plot_type: str
    x_axis: str
    y_axis: str
    color: Optional[str] = None
    size: Optional[str] = None
    index: int = 0

# Create array of visualization goals
goals = [
    Goal(
        question="How does trip distance vary with passenger counts??",
        visualization="Create a scatter showing trip distance distribution for different passenger counts",
        rationale="This will help identify if there's a relationship between number of passengers and trip length",
        plot_type="scatter",
        x_axis="passenger_count",
        y_axis="trip_distance",
        index=0
    ),
    Goal(
        question="What is the distribution of fares throughout the ddays?",
        visualization="Create a line plot showing average fare amount by hour of day",
        rationale="This helps identify peak pricing periods",
        plot_type="line",
        x_axis="hour",
        y_axis="fare_amount",
        index=1
    ),
    Goal(
        question="How do tips vary with total fffare aamount?",
        visualization="Create a scatter plot of tip amount vs total fare",
        rationale="This shows tipping patterns based on fare amounts",
        plot_type="scatter",
        x_axis="total_amount",
        y_axis="tip_amount",
        index=2
    ),
    Goal(
        question="When are the busiest times for tttaxi pickups?",
        visualization="Create a bar chart showing the number of pickups by hour of the day.",
        rationale="This helps identify peak demand hours for taxi services.",
        plot_type="bar",
        x_axis="hour",
        y_axis="pickup_count",
        index=3
    ),
    Goal(
        question="What are the most commonn pickup and dropoff locations?",
        visualization="Create a heatmap showing density of pickups and dropoffs based on longitude and latitude.",
        rationale="This identifies areas with the highest taxi activity.",
        plot_type="heatmap",
        x_axis="pickup_longitude",
        y_axis="pickup_latitude",
        color="density",
        index=4
    ),
    Goal(
        question="How does payment methoddd influence tipping behavior?",
        visualization="Create a boxplot showing tip amounts for each payment type.",
        rationale="This helps understand if passengers tip more with specific payment methods.",
        plot_type="boxplot",
        x_axis="payment_type",
        y_axis="tip_amount",
        index=5
    ),
    Goal(
        question="How do toll amounts impaaact the total fare?",
        visualization="Create a scatter plot of toll amounts vs total fare.",
        rationale="This examines the relationship between tolls and the total amount paid.",
        plot_type="scatter",
        x_axis="tolls_amount",
        y_axis="total_amount",
        index=6
    )
]

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['passenger_count', 'trip_distance'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, 'passenger_count', 'trip_distance')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)

# %%
charts[0]
# Out:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, 'passenger_count', 'trip_distance')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['dday', 'fare_amount'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, 'dday', 'fare_amount')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['total_amount', 'tip_amount'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.points(data, 'total_amount', 'tip_amount')
#     img = tf.shade(agg)
#     return img
# chart = plot(data)
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['hour', 'pickup_count'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, 'hour', 'pickup_count')
#     img = ds.transfer_functions.dynspread(agg)
#     return img
# chart = plot(data)
# import datashader as ds
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['pickup_longitude', 'pickup_latitude'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     # Assuming pickup and dropoff locations are latitude and longitude coordinates
#     pickup_lat = 'pickup_latitude'
#     pickup_lon = 'pickup_longitude'
#     dropoff_lat = 'dropoff_latitude'
#     dropoff_lon = 'dropoff_longitude'
#     # Create a canvas for plotting
#     cvs = ds.Canvas(plot_width=800, plot_height=600)
#     # Aggregate pickup and dropoff locations
#     pickup_agg = cvs.points(data, pickup_lon, pickup_lat)
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['payment_method', 'tip_amount'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#     canvas = ds.Canvas(plot_width=400, plot_height=400)
#     agg = canvas.line(data, 'payment_method', 'tip_amount')
#     img = ds.transfer_functions.dynspread(ds.transfer_functions.shade(agg))
#     return img
# chart = plot(data)
# import datashader as ds
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[6],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: "None of [Index(['tolls_amount', 'total_amount'], dtype='object')] are in the [columns]"
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, pd.DataFrame):
#         canvas = ds.Canvas(plot_width=400, plot_height=400)
#         agg = canvas.points(data, "tolls_amount", "total_amount")
#         img = ds.tf.shade(agg)
#         return img
# chart = plot(data)
# import datashader as ds
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, pd.DataFrame):
#         canvas = ds.Canvas(plot_width=400, plot_height=400)
#         agg = canvas.points(data, "tolls_amount", "total_amount")
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Could not interpret value `passenger_count` for `x`. An entry with this name does not appear in `data`.
# ERROR:lida.components.executor:Code that caused error:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='passenger_count', y='trip_distance')
#     return sns
# chart = plot(data)
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='passenger_count', y='trip_distance')
#     return sns
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.histplot(data=data, x='price', hue='condition', multiple='stack', shrink=0.8)
#     plt.xlabel('Price')
#     plt.ylabel('Frequency')
#     plt.title('Distribution of Fares Throughout the Day')
#     return plt
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Could not interpret value `total_amount` for `x`. An entry with this name does not appear in `data`.
# ERROR:lida.components.executor:Code that caused error:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     sns.scatterplot(data=data, x='total_amount', y='tip_amount')
#     plt.xlabel('Total Amount')
#     plt.ylabel('Tip Amount')
#     plt.title('How do tips vary with total fare amount?')
#     return plt
#
# chart = plot(data)
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import dask.dataframe as dd
#
# def plot(data):
#     sns.histplot(data=data, x='year', hue='condition', multiple='stack')
#     plt.xlabel('Year')
#     plt.ylabel('Frequency')
#     plt.title('Vehicle Auction Frequency by Year and Condition')
#     return plt
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Could not interpret value `pickup_longitude` for `x`. An entry with this name does not appear in `data`.
# ERROR:lida.components.executor:Code that caused error:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='pickup_longitude', y='pickup_latitude')
#     plt.xlabel('Pickup Longitude')
#     plt.ylabel('Pickup Latitude')
#     plt.title('Most Common Pickup and Dropoff Locations')
#     return plt
# chart = plot(data)
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='pickup_longitude', y='pickup_latitude')
#     plt.xlabel('Pickup Longitude')
#     plt.ylabel('Pickup Latitude')
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Could not interpret value `payment_method` for `x`. An entry with this name does not appear in `data`.
# ERROR:lida.components.executor:Code that caused error:
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import dask.dataframe as dd
#
# def plot(data):
#     sns.barplot(data=data, x='payment_method', y='tip_amount')
#     plt.xlabel('Payment Method')
#     plt.ylabel('Average Tip Amount')
#     plt.title('How does payment method influence tipping behavior?')
#     return plt
# chart = plot(data)
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import dask.dataframe as dd
#
# def plot(data):
#     sns.barplot(data=data, x='payment_method', y='tip_amount')
#     plt.xlabel('Payment Method')
#     plt.ylabel('Average Tip Amount')
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[6],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: Could not interpret value `tolls_amount` for `x`. An entry with this name does not appear in `data`.
# ERROR:lida.components.executor:Code that caused error:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='tolls_amount', y='total_amount')
#     return sns
# chart = plot(data)
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     sns.scatterplot(data=data, x='tolls_amount', y='total_amount')
#     return sns
# chart = plot(data)

# %%
ffg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 ffg
#
# NameError: name 'ffg' is not defined

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if hasattr(data, 'compute'):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     if hasattr(data, 'compute'):
#         data = data.compute()
#     # Convert pickup datetime to hour of day
#     data["hour"] = pd.to_datetime(data["tpep_pickup_datetime"]).dt.hour
#     # Create a canvas and aggregate data
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, "hour", "fare_amount")
#     # Shade the aggregation and return the image
#     img = tf.shade(agg)
#     return img
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# ERROR:lida.components.executor:Error executing code: source must be a pandas or dask DataFrame
# ERROR:lida.components.executor:Code that caused error:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
# import matplotlib.pyplot as plt
#
# def plot(data):
#     if hasattr(data, 'compute'):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     if hasattr(data, 'compute'):
#         data = data.compute()
#     # Create a canvas with specified dimensions
#     canvas = ds.Canvas(plot_width=600, plot_height=400)
#     # Aggregate data points using total_amount and tip_amount columns
#     agg = canvas.points(data, 'total_amount', 'tip_amount')
#     # Create a heatmap using the aggregated data
#     img = tf.shade(agg, cmap=['lightblue', 'darkblue'])
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#
#     sns.scatterplot(data=data, x="total_amount", y="tip_amount")
#     plt.xlabel("Total Fare Amount")
#     plt.ylabel("Tip Amount")
#     plt.title("How do tips vary with total fare amount?")
#
#     return plt
#
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#
#     sns.scatterplot(
#         data=data, x="pickup_longitude", y="pickup_latitude", alpha=0.4
#     )
#     sns.scatterplot(
#         data=data, x="dropoff_longitude", y="dropoff_latitude", color="red", alpha=0.4
#     )
#     plt.xlabel("Longitude")
#     plt.ylabel("Latitude")
#     plt.title("Most Common Pickup and Dropoff Locations")
#     return plt
#
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[5],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Code fixed with rules or already valid
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#
#     sns.boxplot(x="payment_type", y="tip_amount", data=data)
#     plt.xlabel("Payment Type")
#     plt.ylabel("Tip Amount")
#     plt.title("How does payment method influence tipping behavior?")
#
#     return plt
#
#
# chart = plot(data)

# %%
viz_gen = VizGenerator(model_type='cohere',
    model_name='command-xlarge-nightly',
    api_key='3lEw7dPhMiInEez7n1CDJg0OumZNrqogGSeKfGaE')

# %%
repair_agent = CodeRepairAgent(text_gen=text_gen, 
                             textgen_config=textgen_config)

# %%
codez = viz_gen.generate(summary=summary, goal=goals[1],textgen_config=textgen_config, library='datashader')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 codez = viz_gen.generate_viz(summary=summary, goal=goals[1],textgen_config=textgen_config, library='datashader')
#
# AttributeError: 'VizGenerator' object has no attribute 'generate_viz'

# %%
test_code1 ="""
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import dask.dataframe as dd

def plot(data):
    if isinstance(data, dd.DataFrame):
        data = data.compute()

    # Convert hour to a 24-hour format for plotting
    data['hour'] = data['hour'].apply(lambda x: x if 0 <= x < 24 else None)

    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.line(data, 'hour', 'fare_amount')
    img = tf.shade(agg)
    return img

chart = plot(df1)
"""

# %%
test_code = """
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import dask.dataframe as dd


def plot(data):
    if isinstance(data, dd.DataFrame):
        data = data.sample(frac=0.1).compute()3moz3laaaan

    sns.boxplot(x="payment_type", y="tip_amount", data=data)
    plt.xlabel("Payment Type")
    plt.ylabel("Tip Amount")
    plt.title("How does payment method influence tipping behavior?")

    return plt

chart = plot(data)
"""

# %%
fixed_coded = repair_agent.repair(test_code)
# Out:
# INFO:code_repair_agent:Starting repair process...
# INFO:code_repair_agent:Rule-based repair failed, attempting LangChain fix
# ...

# %%
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1).compute()
#     sns.boxplot(x="payment_type", y="tip_amount", data=data)
#     plt.xlabel("Payment Type")
#     plt.ylabel("Tip Amount")
#     plt.title("Payment Method and Tipping Behavior")
#     return plt.gcf()  # Return the figure object
# chart = plot(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd


def plot(data):
    # Check data type and handle Dask DataFrame
    if isinstance(data, dd.DataFrame):
        data = data.compute()

    # Create a boxplot using Seaborn
    sns.boxplot(x="payment_type", y="tip_amount", data=data)

    # Set labels and title
    plt.xlabel("Payment Type")
    plt.ylabel("Tip Amount")
    plt.title("Payment Method vs Tip Amount")

    # Return the visualization
    return plt.show()

chart = plot(df1)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[4],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:lida.components.executor:
# ...
# INFO:lida.components.executor:EXECUTING VISUALIZATION CODE
# INFO:lida.components.executor:==================================================
# INFO:lida.components.executor:Processing code for datashader:
# INFO:lida.components.executor:Original code:
# ```python
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Aggregate pickup and dropoff locations
#     pickup_agg = ds.Canvas().points(data, "pickup_longitude", "pickup_latitude")
#     dropoff_agg = ds.Canvas().points(data, "dropoff_longitude", "dropoff_latitude")
#
#     # Create images
#     pickup_img = tf.shade(pickup_agg)
#     dropoff_img = tf.shade(dropoff_agg)
#
#     # Combine images side by side
#     combined_img = tf.Images(pickup_img, dropoff_img).cols(1)
#
#     return combined_img
#
# chart = plot(data)
# ```
# ...

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# INFO:lida.components.executor:
# ...
# INFO:lida.components.executor:EXECUTING VISUALIZATION CODE
# INFO:lida.components.executor:==================================================
# INFO:lida.components.executor:Processing code for datashader:
# INFO:lida.components.executor:Original code:
# ```python
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Filter relevant columns
#     data = data[["passenger_count", "trip_distance"]]
#
#     # Create a canvas and aggregate data
#     canvas = ds.Canvas(plot_width=600, plot_height=400)
#     agg = canvas.line(data, "passenger_count", "trip_distance")
#
#     # Shade the aggregated data
#     img = tf.shade(agg)
#
#     return img
#
# chart = plot(data)
# ```
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# ...

# %%
asfsaf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 asfsaf
#
# NameError: name 'asfsaf' is not defined

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
#
# def plot(data):
#     if hasattr(data, 'compute'):
#         data = data.compute()
#
#     # Convert pickup datetime to hour of day
#     data["hour"] = pd.to_datetime(data["tpep_pickup_datetime"]).dt.hour
#
#     # Create a canvas and aggregate data
#     canvas = ds.Canvas(plot_width=800, plot_height=600)
#     agg = canvas.line(data, "hour", "fare_amount")
#
#     # Shade the aggregation and return the image
#     img = tf.shade(agg)
#     return img
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[0],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data[['passenger_count', 'trip_distance']].sample(frac=0.1, random_state=42).compute()
#
#     sns.scatterplot(data=data, x='passenger_count', y='trip_distance')
#     plt.xlabel('Passenger Count')
#     plt.ylabel('Trip Distance (miles)')
#     plt.title('How does trip distance vary with passenger count?')
#     return plt
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# <string>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data[['tpep_pickup_datetime', 'fare_amount']].sample(frac=0.1, random_state=42).compute()
#     else:
#         data = data[['tpep_pickup_datetime', 'fare_amount']]
#
#     data['hour'] = pd.to_datetime(data['tpep_pickup_datetime']).dt.hour
#
#     sns.boxplot(x="hour", y="fare_amount", data=data)
#     plt.xlabel('Hour of Day')
#     plt.ylabel('Fare Amount')
#     plt.title('Distribution of Fares Throughout the Day')
#     return plt
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# ERROR:lida.components.executor:Error executing code: No chart object was created
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Create a canvas with specified dimensions
#     canvas = ds.Canvas(plot_width=600, plot_height=400)
#
#     # Aggregate data points using total_amount and tip_amount columns
#     agg = canvas.points(data, 'total_amount', 'tip_amount')
#
#     # Create a heatmap using the aggregated data
#     img = tf.shade(agg, cmap=['lightblue', 'darkblue'])
#
#     # Return the image/visualization
#     return img
#
# # Placeholder for the data
# data = None
#
# # Call the plot function and assign the result to chart
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]
# Out:
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
# import dask.dataframe as dd
#
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.sample(frac=0.1, random_state=42).compute()
#
#     sns.scatterplot(data=data, x="total_amount", y="tip_amount")
#     plt.xlabel("Total Fare Amount")
#     plt.ylabel("Tip Amount")
#     plt.title("How do tips vary with total fare amount?")
#
#     return plt
#
#
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[2],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# ERROR:lida.components.executor:Error executing code: No chart object was created
# import datashader as ds
# import datashader.transfer_functions as tf
# import pandas as pd
# import dask.dataframe as dd
#
# def plot(data):
#     if isinstance(data, dd.DataFrame):
#         data = data.compute()
#
#     # Create a canvas with specified dimensions
#     canvas = ds.Canvas(plot_width=600, plot_height=400)
#
#     # Aggregate data points using total_amount and tip_amount columns
#     agg = canvas.points(data, 'total_amount', 'tip_amount')
#
#     # Create a heatmap using the aggregated data
#     img = tf.shade(agg, cmap=['lightblue', 'darkblue'])
#
#     # Return the image/visualization
#     return img
#
# # Placeholder for the data
# data = None
#
# # Call the plot function and assign the result to chart
# chart = plot(data)

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 4
#       1 charts = manager.visualize(
#       2     data=df1,
#       3     summary=summary,
# ----> 4     goal=goals[3],  # or any other goal from the list
#       5     textgen_config=textgen_config,
#       6     library='datashader',
#       7     return_error=True
#       8 )
#       9 charts[0]
#
# IndexError: list index out of range

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[3],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True
)
charts[0]

# %%
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goals[1],  # or any other goal from the list
    textgen_config=textgen_config,
    library='datashader',
    return_error=True
)
charts[0]

# %%
charts

# %%
# Set up logging to see the repair process
import logging
logging.basicConfig(level=logging.INFO)
logging.getLogger("lida.code_repair").setLevel(logging.DEBUG)

# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
print("\nFinal visualization code:")
print(charts[0].code if charts else "No charts generated")

# %%
# You'll see detailed output of the repair process

# %%
charts[0]

# %%
if charts:
    chart_code = charts[0].code
    print("Generated Chart Code:")
    print(chart_code)
else:
    print("No charts were generated. Please check for errors.")

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[3]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import dask.dataframe as dd
from colorcet import fire  # Optional color map

def plot(data):
    if isinstance(data, dd.DataFrame):
        data = data.sample(frac=0.1, random_state=42).compute()
    # Insert plotting code below. Example:
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, 'population', 'median_income')
    img = tf.shade(agg, cmap=fire)
    return img

chart = plot(df1)
chart

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import dask.dataframe as dd
from colorcet import fire  # Optional color map

def plot(data):
    if isinstance(data, dd.DataFrame):
        data = data.sample(frac=0.1, random_state=42).compute()
    # Insert plotting code below. Example:
    canvas = ds.Canvas(plot_width=800, plot_height=600)
    agg = canvas.points(data, 'housing_median_age', 'total_rooms')
    img = tf.shade(agg, cmap=fire)
    return img

chart = plot(df1)
chart

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[4]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df1,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
import pandas as pd
import datashader as ds
import datashader.transfer_functions as tf

def plot(data):
    # Convert data to pandas DataFrame
    data_df = pd.DataFrame(data)
    
    # Create a canvas and plot the data
    cvs = ds.Canvas(plot_width=400, plot_height=400)
    agg = cvs.points(data_df, 'trip_distance', 'passenger_count')
    img = tf.shade(agg)
    
    # Return the image
    return img
chart = plot(df1)

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import dask.dataframe as dd
from colorcet import fire

def plot(data):
    # Convert 'tpep_pickup_datetime' and 'tpep_dropoff_datetime' to datetime objects
    data['tpep_pickup_datetime'] = pd.to_datetime(data['tpep_pickup_datetime'])
    data['tpep_dropoff_datetime'] = pd.to_datetime(data['tpep_dropoff_datetime'])
    
    # Create a Datashader Canvas
    cvs = ds.Canvas()
    
    # Aggregate data by binning pickup and dropoff locations and time of day
    agg = cvs.points(data, 'pickup_longitude', 'pickup_latitude', ds.by('tpep_pickup_datetime.hour', 'tpep_dropoff_datetime.hour'))
    
    # Create a heatmap using the aggregated data
    img = tf.shade(agg, cmap=fire)
    
    return img

# Example usage:
chart = plot(df)

# %%
import dask.dataframe as dd
import datashader as ds
import datashader.transfer_functions as tf
from datashader.utils import export_image
import colorcet as cc
import pandas as pd

def plot(data):
    
    # Define the canvas
    canvas = ds.Canvas(plot_width=800, plot_height=600, 
                       x_range=(data['pickup_longitude'].min().compute(), data['dropoff_longitude'].max().compute()), 
                       y_range=(data['pickup_latitude'].min().compute(), data['dropoff_latitude'].max().compute()))
    
    # Aggregate the data
    agg = canvas.points(data, 'pickup_longitude', 'pickup_latitude', agg=ds.count_cat('tpep_pickup_datetime'))
    
    # Create the heatmap
    img = tf.shade(agg, cmap=cc.fire)
    
    # Export the image
    export_image(img, 'heatmap')
    
    return img

# Example usage
# Assuming 'data' is your Dask DataFrame containing the taxi trip data
# data = dd.read_csv('your_data.csv')
plot(df)

# %%
import dask.dataframe as dd
import datashader as ds
import datashader.transfer_functions as tf
from datashader.utils import export_image

# Create a Dask DataFrame
df = dd.read_csv('F:/eeeeee/lida/data.csv')

# Create a Canvas

# %%
canvas = ds.Canvas(plot_width=800, plot_height=600)

# Aggregate the data
agg = canvas.points(df, 'A', 'E')

# Create an image
img = tf.shade(agg)

# Export the image
export_image(img, 'output_image')

# %%
import lida
print("LIDA module location:", lida.__file__)

# %%
# Import required libraries
import os
from lida import Manager, TextGenerationConfig
import pandas as pd

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='plotly',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import time

# Start timer
start_time = time.time()

# Simple scatter plot of trip_distance vs fare_amount
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x='trip_distance', y='fare_amount', alpha=0.5)

# Add labels and title
plt.xlabel('Trip Distance')
plt.ylabel('Fare Amount')
plt.title('Scatter Plot of Trip Distance vs Fare Amount')
plt.tight_layout()

# Show the plot
plt.show()

# End timer and print execution time
end_time = time.time()
print(f"Execution Time: {end_time - start_time:.2f} seconds")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure you are working with a Pandas DataFrame (not Dask DataFrame) for this operation
if not isinstance(df, pd.DataFrame):
    df = df.compute()

# Binning 'trip_distance' into 10 bins
binned_distances = pd.cut(df['trip_distance'], bins=10)

# Convert binned distances to string to avoid issues with Categorical types
df['binned_distance'] = binned_distances.astype(str)

# Aggregating 'fare_amount' (mean fare amount per distance bin)
aggregated_data = df.groupby('binned_distance').agg({'fare_amount': 'mean'}).reset_index()

# Plotting the aggregated data using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(data=aggregated_data, x='binned_distance', y='fare_amount', palette='viridis')

# Adding labels and title
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Trip Distance (Binned)')
plt.ylabel('Mean Fare Amount')
plt.title('Mean Fare Amount Across Binned Trip Distances')
plt.tight_layout()

# Show the plot
plt.show()

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd

# Preprocess the data and create a DataFrame

def plot(data_df):
    # Create a canvas and aggregate points with color encoding for median income
    cvs = ds.Canvas()
    agg = cvs.points(data_df, 'longitude', 'latitude', ds.mean('median_income'))
    
    # Define a color map for income ranges with equal intervals
    color_map = ['blue', 'green', 'yellow', 'red']
    
    # Shade the aggregate data using the color map and equal-interval binning
    img = tf.shade(agg, cmap=color_map, how='eq_hist')
    
    return img
chart = plot(df)
chart

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
from colorcet import fire

def preprocess_data(data):
    # If needed, add preprocessing steps here
    return data

def plot_income_distribution(data):
    # Preprocess data
    data = preprocess_data(data)
    
    # Create a canvas and project the data
    cvs = ds.Canvas(plot_width=400, plot_height=400)
    img = cvs.points(data, 'longitude', 'latitude', ds.mean('median_income'))

    # Apply colormap and display the image
    img = tf.shade(img, cmap=fire)
    img = tf.set_background(img, "black")
    return img

# Data is already loaded
data = preprocess_data(df)
chart = plot_income_distribution(df)
chart

# %%
dasasd

# %%
import plotly.express as px

def create_density_plot(data, x_field, y_field, title):
    fig = px.density_heatmap(data, x=x_field, y=y_field, marginal_x="histogram", marginal_y="histogram", histfunc="avg")
    fig.update_layout(title=title)
    return fig

# Assuming 'data' is your DataFrame with the required fields
density_plot = create_density_plot(df, 'median_income', 'median_house_value', 'Median House Value Distribution by Income')
density_plot.show()
chart = plot(df)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    data=df,
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='plotly',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
import datashader as ds
import pandas as pd

def plot(data):
    # Convert Dask DataFrame to Pandas DataFrame if needed
    if hasattr(data, "compute"):
        data = data.compute()

    # Data preprocessing
    df = pd.DataFrame(data)  # Ensure data is a Pandas DataFrame
    df["pickup_longitude"] = pd.to_numeric(df["pickup_longitude"], errors="coerce")
    df["pickup_latitude"] = pd.to_numeric(df["pickup_latitude"], errors="coerce")
    df["trip_distance"] = pd.to_numeric(df["trip_distance"], errors="coerce")

    # Filter out rows with NaN values in the relevant columns
    df = df.dropna(subset=["pickup_longitude", "pickup_latitude", "trip_distance"])

    # Create a Canvas object
    cvs = ds.Canvas(plot_width=800, plot_height=600)

    # Aggregate data to create a heatmap
    agg = cvs.points(df, "pickup_longitude", "pickup_latitude", ds.mean("trip_distance"))

    # Create a heatmap image
    img = tf.shade(agg, cmap="red", how="log")

    return img

chart = plot(data)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
from colorcet import fire

def plot(data, width=800, height=600):
    try:
        # Convert Dask DataFrame to Pandas if needed
        if "dask" in str(type(data)):
            data = data.compute()

        # Validate data types and handle missing values
        data = pd.DataFrame(data)
        numeric_cols = data.select_dtypes(include=[float, int]).columns
        if len(numeric_cols) < 2:
            raise ValueError("At least 2 numeric columns are required for visualization.")

        # Select columns for visualization
        x_col = "median_income"
        y_col = "median_house_value"
        if x_col not in numeric_cols or y_col not in numeric_cols:
            raise ValueError("Selected columns are not numeric.")

        # Handle missing values
        data.fillna(0, inplace=True)

        # Create canvas and aggregate
        cvs = ds.Canvas(plot_width=width, plot_height=height)
        agg = cvs.points(data, x_col, y_col)

        # Create final image with shading and colormap
        img = tf.shade(agg, cmap=fire)

        return img

    except Exception as e:
        print(f"Error creating visualization: {str(e)}")
        raise

# Example usage:
chart = plot(data)
chart

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import numpy as np

def plot(data):
    # Handle Dask DataFrame
    if "dask" in str(type(data)):
        data = data.compute()

    # Validate data
    if not isinstance(data, pd.DataFrame):
        raise TypeError("Data must be a Pandas or Dask DataFrame")

    # Identify columns for visualization
    x_col = "median_income"
    y_col = "median_house_value"

    # Check if columns exist in the DataFrame
    if x_col not in data.columns or y_col not in data.columns:
        raise ValueError("Required columns not found in the DataFrame")

    # Create a Datashader canvas
    cvs = ds.Canvas(plot_width=800, plot_height=600)
    agg = cvs.points(data, x=x_col, y=y_col)

    # Create the image
    img = tf.shade(agg, cmap=["lightblue", "darkblue"], how="eq_hist")

    # Overlay with Matplotlib
    img = tf.set_background(img, 'white')
    plt.figure(figsize=(12, 8))
    plt.title("Median House Value vs Income")
    plt.xlabel("Median Income")
    plt.ylabel("Median House Value")
    plt.show()

    return img

chart = plot(data)
chart

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
from colorcet import fire
def plot(data):
    # Handle Dask DataFrame if necessary
    if hasattr(data, "compute"):
        data = data.compute()

    # Preprocessing: Convert relevant columns to float/integer
    data["median_income"] = data["median_income"].astype(float)
    data["latitude"] = data["latitude"].astype(float)
    data["longitude"] = data["longitude"].astype(float)

    # Create a Canvas object
    cvs = ds.Canvas(plot_width=400, plot_height=400)

    # Aggregate data to create a Heatmap
    agg = cvs.points(data, "longitude", "latitude", ds.mean("median_income"))

    # Create a shaded Heatmap
    img = tf.shade(agg, cmap=fire, how="log")

    return img

chart = plot(data)
chart

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[3]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[3]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='plotly',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  

charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[2]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[1]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='seaborn',
    return_error=True  # Include this to capture errors
)

# %%
charts[0]

# %%
# Choose a goal to visualize
goal_to_visualize = goals[3]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
# Choose a goal to visualize
goal_to_visualize = goals[4]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader',
    return_error=True  # Include this to capture errors
)

# %%
goal_to_visualize = goals[1]

# Visualize using the 'seaborn' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library="seaborn",
    return_error=True
)

# %%
from IPython.display import display
from PIL import Image
import base64
import io

for chart in charts:
    if chart.status:
        if chart.raster:
            img_data = base64.b64decode(chart.raster)
            img = Image.open(io.BytesIO(img_data))
            display(img)
        else:
            print("No raster data available.")
    else:
        print(f"Chart failed to generate: {chart.error['message']}")
        print(f"Traceback:\n{chart.error['traceback']}")
        print("Generated code:")
        print(chart.code)

# %%
"""# Display the chart or print errors
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def plot(data: pd.DataFrame):
    # Sample a fraction of the data if necessary
    if isinstance(data, dd.DataFrame):
        sample_fraction = 0.1  # Adjust as needed
        data = data.sample(frac=sample_fraction, random_state=42).compute()
    else:
        data = data.dropna()

    sns.pairplot(data, kind='reg')
    plt.suptitle('Are there any correlations between the columns?', wrap=True)
    return plt

chart = plot(ddf)
"""

# %%
# Choose a goal to visualize
goal_to_visualize = goals[0]  # Or any other goal from the list

# Visualize using the 'datashader' library
charts = manager.visualize(
    summary=summary,
    goal=goal_to_visualize,
    textgen_config=textgen_config,
    library='datashader'
)

# %%
"""from lida.utils import plot_raster

for chart in charts:
    if chart.status:
        if chart.raster:
            plot_raster(chart.raster)
        else:
            print("No raster data available.")
    else:
        print(f"Chart failed to generate: {chart.error}")"""

# %% [markdown]
# # Old Testing

# %%
import logging
import json
import pandas as pd
from lida.components.summarizer import Summarizer
from lida.components.goal import GoalExplorer
from lida.utils import read_dataframe
from llmx import llm  # Import the factory function
from lida.datamodel import TextGenerationConfig

logging.basicConfig(level=logging.INFO)


text_gen = llm(provider="cohere", model="command-xlarge-nightly", api_key="LEIGRdhkjZP0KBrcpp9Z77YfwL2vOuGfZJxKmmEY")

# Adjusted text generation configuration using TextGenerationConfig class
textgen_config = TextGenerationConfig(
    n=1,
    temperature=0.5,
    model="command-xlarge-nightly",
    use_cache=True,
    max_new_tokens=100
)

# Instantiate your updated summarizer
summarizer = Summarizer()


#ddf = dd.from_pandas(data, npartitions=10)  # Create Dask DataFrame

# Step 1: Summarize the dataset using your updated summarizer
try:
    summary = summarizer.summarize(
        data=ddf,
        text_gen=text_gen,
        file_name="large_test_data.csv",
        n_samples=3,
        textgen_config=textgen_config,
        summary_method="default"  # Use 'llm' for enrichment using LLM if needed
    )

    # Convert summary to native Python types to fix JSON serialization issue
    # Function to recursively convert data types to JSON-serializable formats
    def convert_types(obj):
        if isinstance(obj, dict):
            return {k: convert_types(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [convert_types(i) for i in obj]
        elif isinstance(obj, (pd.Series, dd.Series)):
            return obj.tolist()  # Convert Series to list
        elif isinstance(obj, (pd.Timestamp, pd.Timedelta)):
            return str(obj)  # Convert Timestamp or Timedelta to string
        elif hasattr(obj, "dtype") and obj.dtype == "int64":
            return obj.item() if obj.ndim == 0 else obj.tolist()  # Convert scalar or series
        elif isinstance(obj, (np.int64, np.float64)):  # Handle numpy data types
            return obj.item()  # Convert scalar numpy types to native Python types
        elif isinstance(obj, (int, float, str)):
            return obj  # Native Python types are already JSON-serializable
        else:
            return str(obj)  # Fallback for unsupported types

# Applying this function to the `summary`
    summary = convert_types(summary)


    # Print the generated summary
    print("Generated Summary:")
    print(json.dumps(summary, indent=2))

except Exception as e:
    print("Error during summarization:", e)

# %%
# Step 2: Use GoalExplorer to generate goals based on the summary
goal_explorer = GoalExplorer()

# Number of goals to generate
n_goals = 3

# Generate the goals using GoalExplorer
try:
    goals = goal_explorer.generate(
        summary=summary,
        textgen_config=textgen_config,
        text_gen=text_gen,
        n=n_goals
    )

    # Print the generated goals
    print("\nGenerated Goals:")
    for goal in goals:
        print(goal)

except Exception as e:
    print("Error during goal generation:", e)

# %%
from lida.components.viz.vizgenerator import VizGenerator

# Step 3: Use VizGenerator to create visualizations based on the goals
viz_generator = VizGenerator()

# Specify the library to be used for visualization
# Use 'datashader' for large datasets, as previously incorporated in your changes
library = "seaborn"

# Try generating visualization code using the VizGenerator
try:
    # Generate visualization code for the first goal as an example
    visualization_code = viz_generator.generate(
        summary=summary,
        goal=goals[0],  # Use the first goal for this example
        textgen_config=textgen_config,
        text_gen=text_gen,
        library=library  # Specify Datashader for efficient visualization with large datasets
    )

    # Print the generated visualization code
    print("\nGenerated Visualization Code:")
    print(visualization_code)

except Exception as e:
    print("Error during visualization generation:", e)

# %%
import logging
from PIL import Image
import io
import base64
from lida.datamodel import TextGenerationConfig
from lida.components.manager import Manager

# Set up logging
logging.basicConfig(level=logging.INFO)

# Step 1: Initialize the Manager
# Provide text generation (if required) otherwise leave it as default (None)
manager = Manager(text_gen=text_gen)

# Step 2: Summarize the data
# Use the dataset you have; here, we assume you already have a Dask or Pandas DataFrame
summary = manager.summarize(
    data=ddf,  # Using the large Dask DataFrame we created earlier
    file_name="large_test_data.csv",
    n_samples=3,
    summary_method="default",
    textgen_config=textgen_config
)

# Step 3: Generate goals from the summary
n_goals = 3
goals = manager.goals(
    summary=summary,
    textgen_config=textgen_config,
    n=n_goals
)

# Step 4: Generate and execute the visualization based on one of the goals
try:
    # Here we use the first generated goal
    chart_response = manager.visualize(
        summary=summary,
        goal=goals[0],
        textgen_config=textgen_config,
        library="seaborn"  # Since the data is large, use Datashader for efficient visualization
    )

    # Step 5: Display the chart from the ChartExecutorResponse
    # Check if the response is valid and if the raster attribute is present
    if chart_response and chart_response.status:
        print("Chart generated successfully.")
        print(f"Raster data size: {len(chart_response.raster)} bytes")

        # Decode the base64 raster data
        img_data = base64.b64decode(chart_response.raster)
        img = Image.open(io.BytesIO(img_data))

        # Use IPython display to show the image in Google Colab
        display(img)
    else:
        print("No valid chart was generated or an error occurred.")

except Exception as e:
    print("Error during visualization generation or execution:", e)

# %%
import logging
from PIL import Image
import io
import base64
from lida.datamodel import TextGenerationConfig
from lida.components.manager import Manager

# Set up logging
logging.basicConfig(level=logging.INFO)

# Step 1: Initialize the Manager
# Provide text generation (if required) otherwise leave it as default (None)
manager = Manager(text_gen=text_gen)

# Step 2: Summarize the data
# Use the dataset you have; here, we assume you already have a Dask or Pandas DataFrame
summary = manager.summarize(
    data=ddf,  # Using the large Dask DataFrame we created earlier
    file_name="large_test_data.csv",
    n_samples=3,
    summary_method="default",
    textgen_config=textgen_config
)

# Step 3: Generate goals from the summary
n_goals = 3
goals = manager.goals(
    summary=summary,
    textgen_config=textgen_config,
    n=n_goals
)

# Step 4: Generate and execute the visualization based on one of the goals
try:
    # Here we use the first generated goal
    chart_response = manager.visualize(
        summary=summary,
        goal=goals[1],
        textgen_config=textgen_config,
        library="datashader"  # Since the data is large, use Datashader for efficient visualization
    )

    # Step 5: Display the chart from the ChartExecutorResponse
    # Check if the response is valid and if the raster attribute is present
    if chart_response and chart_response.status:
        print("Chart generated successfully.")
        print(f"Raster data size: {len(chart_response.raster)} bytes")

        # Decode the base64 raster data
        img_data = base64.b64decode(chart_response.raster)
        img = Image.open(io.BytesIO(img_data))

        # Use IPython display to show the image in Google Colab
        display(img)
    else:
        print("No valid chart was generated or an error occurred.")

except Exception as e:
    print("Error during visualization generation or execution:", e)

# %%
import logging
from PIL import Image
import io
import base64
from lida.datamodel import TextGenerationConfig
from lida.components.manager import Manager

# Set up logging
logging.basicConfig(level=logging.INFO)

# Step 1: Initialize the Manager
# Provide text generation (if required) otherwise leave it as default (None)
manager = Manager(text_gen=text_gen)

# Step 2: Summarize the data
# Use the dataset you have; here, we assume you already have a Dask or Pandas DataFrame
summary = manager.summarize(
    data=ddf,  # Using the large Dask DataFrame we created earlier
    file_name="large_test_data.csv",
    n_samples=3,
    summary_method="default",
    textgen_config=textgen_config
)

# Step 3: Generate goals from the summary
n_goals = 3
goals = manager.goals(
    summary=summary,
    textgen_config=textgen_config,
    n=n_goals
)

# Step 4: Generate and execute the visualization based on one of the goals
try:
    # Here we use the first generated goal
    chart_response = manager.visualize(
        summary=summary,
        goal=goals[2],
        textgen_config=textgen_config,
        library="datashader"  # Since the data is large, use Datashader for efficient visualization
    )

    # Step 5: Display the chart from the ChartExecutorResponse
    # Check if the response is valid and if the raster attribute is present
    if chart_response and chart_response.status:
        print("Chart generated successfully.")
        print(f"Raster data size: {len(chart_response.raster)} bytes")

        # Decode the base64 raster data
        img_data = base64.b64decode(chart_response.raster)
        img = Image.open(io.BytesIO(img_data))

        # Use IPython display to show the image in Google Colab
        display(img)
    else:
        print("No valid chart was generated or an error occurred.")

except Exception as e:
    print("Error during visualization generation or execution:", e)

# %%
import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from colorcet import fire

def plot(data: pd.DataFrame):
    # Convert review/time to datetime and drop NaT values
    data['review/time'] = pd.to_datetime(data['review/time'], errors='coerce')
    data = data[pd.notna(data['review/time'])]

    # Ensure there is data to plot
    if data.empty or 'review/time' not in data.columns or 'review/score' not in data.columns:
        raise ValueError("Data is missing required columns or is empty after processing.")

    # Convert review/time to a timestamp to make it numeric for Datashader
    data['timestamp'] = data['review/time'].astype(int) / 10**9  # Convert to seconds

    # Create a canvas to define the area of the plot
    canvas = ds.Canvas(plot_width=800, plot_height=400, x_range=(data['timestamp'].min(), data['timestamp'].max()), y_range=(data['review/score'].min(), data['review/score'].max()))

    # Aggregate data to visualize the average review score over time
    agg = canvas.line(data, 'timestamp', 'review/score', ds.mean('review/score'))

    # Apply a color scheme for better interpretation (e.g., using a heatmap effect)
    img = tf.shade(agg, cmap=fire, how='linear')  # Using a fire color map for a heatmap-like effect

    return img

try:
    # Generate and display the plot
    chart = plot(data)

    # Display the chart using matplotlib for additional customization
    plt.figure(figsize=(10, 5))
    plt.imshow(chart.to_pil(), aspect='auto', extent=[data['review/time'].min(), data['review/time'].max(), data['review/score'].min(), data['review/score'].max()])
    plt.xlabel('Time')
    plt.ylabel('Average Review Score')
    plt.title('Trend of Review Scores Over Time')
    plt.colorbar(plt.cm.ScalarMappable(cmap='inferno'), label='Score Density')
    plt.show()

except Exception as e:
    print("Error during plotting:", e)

# %%
print(ddf.tail())  # Print the first few rows of data to check content
print(ddf.dtypes)  # Check the data types to ensure the columns are numeric

# %%
"""import datashader as ds
import datashader.transfer_functions as tf
import pandas as pd
import numpy as np
import dask.dataframe as dd

# Sample data for testing
num_rows = 6000000
data = pd.DataFrame({
    'x': np.random.uniform(0, 100, num_rows),
    'y': np.random.uniform(0, 100, num_rows),
    'z': np.random.randint(0, 5, num_rows)  # This will be converted to categorical
})

# Convert 'z' to categorical
data['z'] = data['z'].astype('category')

# Convert to a Dask DataFrame for testing
ddf = dd.from_pandas(data, npartitions=10)

def plot(data: dd.DataFrame):
    # Create a canvas to define the plot area
    canvas = ds.Canvas(plot_width=800, plot_height=600)

    # Aggregate data using Datashader's methods
    agg = canvas.points(data, 'x', 'y', ds.by('z', ds.mean('y')))

    # Normalize the aggregated data
    norm = tf.shade(agg, cmap=['blue', 'green', 'red'], how='linear')

    # Return the image
    return norm

# Generate and display the chart
chart = plot(ddf)

# Display the chart using matplotlib
import matplotlib.pyplot as plt
plt.imshow(chart.to_pil())  # Convert to PIL image for display
plt.axis('off')  # Hide axes
plt.show()
"""
